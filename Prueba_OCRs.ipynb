# %% [markdown]
# Carga de paquetes (y en el colab meter la imagen, habrá que quitar lo del google colab)

# %%
import cv2 
import easyocr #OCR que igual ni usamos
import pytesseract  # El ocr bueno
import matplotlib.pyplot as plt
import shutil
import os
import random
try:
 from PIL import Image
except ImportError:
 import Image
 
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'  # Adjust the path based on your installation location
reader = easyocr.Reader(['hi','en'])

# %% [markdown]
# ocr pytesseract para detectar texto directamente (pocho):

# %% [raw]
# image_path_in_colab=".git/"
#
# extractedInformation = pytesseract.image_to_string(Image.open(image_path_in_colab))
# print(pytesseract.image_to_boxes(Image.open(image_path_in_colab)))
# print(extractedInformation)

# %% [markdown]
# ocr easyocr para detectar texto directamente (mejor):

# %% [raw]
# bounds = reader.readtext(image_path_in_colab, detail=0) #detail=0 argument will only give text in array
# print("Output:")
# print(bounds)

# %% [markdown]
# ocr pytesseract para sacar imagenes letra a letra:

# %%
image_path_in_colab= "data\images\WhatsApp Image 2023-11-17 at 12.08.26.jpeg"
image = cv2.imread(image_path_in_colab)

# Convertir a escala de grises
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Aplicar umbralización o técnicas de binarización si es necesario

# Aplicar un filtro de suavizado o técnicas de eliminación de ruido si es necesario

# Detección de bordes con el algoritmo Canny
edged_image = cv2.Canny(gray, threshold1=30, threshold2=100)  # Ajusta los valores de umbral según tu imagen

# Encuentra los contornos en la imagen de bordes
contours, _ = cv2.findContours(edged_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Recorrer los contornos identificados
for i,contour in enumerate(contours):
    # Obtener las coordenadas y dimensiones de cada contorno
    x, y, w, h = cv2.boundingRect(contour)

    # Recortar la región con la letra
    letter_region = image[y:y+h, x:x+w]

    # Aplicar OCR para reconocimiento de texto en la región
    text = pytesseract.image_to_string(letter_region, lang='eng')

    # Guardar la imagen de la letra y el texto reconocido
    cv2.imwrite(f'data\images\letra_{i}.png'.format(text), letter_region)

# %% [raw]
# from google.colab.patches import cv2_imshow
# edged_image = cv2.Canny(gray, threshold1=30, threshold2=100)  # Ajusta los valores de umbral según tu imagen
#
# # Encuentra los contornos en la imagen de bordes
# contours, _ = cv2.findContours(edged_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
# # Recorrer los contornos identificados y mostrar las regiones recortadas
# for contour in contours:
#     x, y, w, h = cv2.boundingRect(contour)
#     letter_region = image[y:y+h, x:x+w]
#     cv2_imshow(letter_region)
#     cv2.waitKey(0)
#
# cv2.destroyAllWindows()

# %% [markdown]
# ocr easyocr para sacar imagenes letra a letra:

# %%
# Convertir a escala de grises
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Aplicar umbralización o técnicas de binarización si es necesario

# Aplicar un filtro de suavizado o técnicas de eliminación de ruido si es necesario

# Configurar EasyOCR
reader = easyocr.Reader(['en'])  # Puedes añadir más idiomas si es necesario

# Encontrar contornos en la imagen de bordes
contours, _ = cv2.findContours(gray, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Recorrer los contornos identificados
for contour in contours:
    # Obtener las coordenadas y dimensiones de cada contorno
    x, y, w, h = cv2.boundingRect(contour)

    # Recortar la región con la letra
    letter_region = image[y:y+h, x:x+w]

    # Convertir la región a RGB (EasyOCR espera imágenes en formato RGB)
    letter_rgb = cv2.cvtColor(letter_region, cv2.COLOR_BGR2RGB)

    # Aplicar EasyOCR para reconocimiento de texto en la región
    result = reader.readtext(letter_rgb)

    if result:
        text = result[0][-2]  # Tomar el texto reconocido

        # Guardar la imagen de la letra y el texto reconocido
        cv2.imwrite('letra_{}.png'.format(text), letter_region)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Propietario\Documents\Master\Analisis_Senyales\Trabajo_Git\Trabajo_ReconocimientoTexto\Prueba_OCRs.ipynb Cell 11 line 9
#       <a href='vscode-notebook-cell:/c%3A/Users/Propietario/Documents/Master/Analisis_Senyales/Trabajo_Git/Trabajo_ReconocimientoTexto/Prueba_OCRs.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#       <a href='vscode-notebook-cell:/c%3A/Users/Propietario/Documents/Master/Analisis_Senyales/Trabajo_Git/Trabajo_ReconocimientoTexto/Prueba_OCRs.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a> # Aplicar umbralización o técnicas de binarización si es necesario
#       <a href='vscode-notebook-cell:/c%3A/Users/Propietario/Documents/Master/Analisis_Senyales/Trabajo_Git/Trabajo_ReconocimientoTexto/Prueba_OCRs.ipynb#X13sZmlsZQ%3D%3D?line=4'>5</a>
#       <a href='vscode-notebook-cell:/c%3A/Users/Propietario/Documents/Master/Analisis_Senyales/Trabajo_Git/Trabajo_ReconocimientoTexto/Prueba_OCRs.ipynb#X13sZmlsZQ%3D%3D?line=5'>6</a> # Aplicar un filtro de suavizado o técnicas de eliminación de ruido si es necesario
#       <a href='vscode-notebook-cell:/c%3A/Users/Propietario/Documents/Master/Analisis_Senyales/Trabajo_Git/Trabajo_ReconocimientoTexto/Prueba_OCRs.ipynb#X13sZmlsZQ%3D%3D?line=6'>7</a>
#       <a href='vscode-notebook-cell:/c%3A/Users/Propietario/Documents/Master/Analisis_Senyales/Trabajo_Git/Trabajo_ReconocimientoTexto/Prueba_OCRs.ipynb#X13sZmlsZQ%3D%3D?line=7'>8</a> # Configurar EasyOCR
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Propietario/Documents/Master/Analisis_Senyales/Trabajo_Git/Trabajo_ReconocimientoTexto/Prueba_OCRs.ipynb#X13sZmlsZQ%3D%3D?line=8'>9</a> reader = easyocr.Reader(['en'])  # Puedes añadir más idiomas si es necesario
#      <a href='vscode-notebook-cell:/c%3A/Users/Propietario/Documents/Master/Analisis_Senyales/Trabajo_Git/Trabajo_ReconocimientoTexto/Prueba_OCRs.ipynb#X13sZmlsZQ%3D%3D?line=10'>11</a> # Encontrar contornos en la imagen de bordes
#      <a href='vscode-notebook-cell:/c%3A/Users/Propietario/Documents/Master/Analisis_Senyales/Trabajo_Git/Trabajo_ReconocimientoTexto/Prueba_OCRs.ipynb#X13sZmlsZQ%3D%3D?line=11'>12</a> contours, _ = cv2.findContours(gray, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#
# NameError: name 'easyocr' is not defined

# %%
imagen = cv2.imread("data\images\letra_16.png")
imagen = cv2.resize(imagen, (28, 28))
ancho, alto, can = imagen.shape
cv2.imwrite(f'data\images\letra_O.png', imagen)
print(alto, ancho)
# Out:
# 28 28
